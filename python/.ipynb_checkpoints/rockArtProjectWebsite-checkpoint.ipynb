# %%
import os
import sys
import glob

# %%
allWordFilesGlob = "/Users/mettinger/Desktop/rockArtProject/**/*.doc*"
routesPath = "/Users/mettinger/github/rockArtProjectWebsite/app/routes.py"

# %%
routeDotPy = '''
from flask import render_template, flash, redirect, request
from app import app
import sys
import os

@app.route('/')
@app.route('/index',methods=['GET', 'POST'])
def index():
    return "hello rock"
'''

# %%
allWordFiles = glob.glob(allWordFilesGlob, recursive=True)

# %%
with open(routesPath,'w') as fp:
    fp.write(routeDotPy)

# %%
allWordFiles
# Out:
# ['/Users/mettinger/Desktop/rockArtProject/blockTwo/case14/Case 14-Mex-Vera Cruz-Classic-Head-600 CE.doc',
#  '/Users/mettinger/Desktop/rockArtProject/blockTwo/case14/Case 14-MEX-Mezcala, Guerrero-Figure-Green Serpentine-Early Preclassic-700-200 BCE.docx',
#  '/Users/mettinger/Desktop/rockArtProject/blockTwo/case14/Case 14-MEX-Mexcala.doc',
#  '/Users/mettinger/Desktop/rockArtProject/blockTwo/case14/Case 14-AM,C-Costa Rica-Guanacast-Nicoya-Figure-Female-Whistle.docx',
#  '/Users/mettinger/Desktop/rockArtProject/blockTwo/case14/Case 14-MEX-Mezcala-Figure-4 5-8 in.doc',
#  '/Users/mettinger/Desktop/rockArtProject/blockTwo/case14/Case 14-MEX-Mezcala Crouching Figures.doc',
#  '/Users/mettinger/Desktop/rockArtProject/blockTwo/case14/Case 14-MEX-Maya-Jaguar-Mortar and Pestle-Classic Period-900 CE.doc',
#  '/Users/mettinger/Desktop/rockArtProject/blockTwo/case14/Case 14-A1341-Peru-Chavin-Jaguar Votary-Crenelated crown-250 BCE.docx',
# ...
